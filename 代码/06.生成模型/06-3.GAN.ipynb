# %%
import os
import torch
import torchvision
import torch.nn as nn
from torchvision import transforms
from torch.nn import functional as F
from torchvision.utils import save_image

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Hyper-parameters
latent_size = 64
hidden_size = 256
image_size = 784
num_epochs = 100
# num_epochs = 5
batch_size = 100
image_dir = './image/gan'
model_path = "./model"

# %%
# Create a directory if not exists
if not os.path.exists(image_dir):
    os.makedirs(image_dir)
if not os.path.exists(model_path):
    os.makedirs(model_path)

# %% [markdown]
# # 数据加载

# %%
# Image processing
# transform = transforms.Compose([
#                 transforms.ToTensor(),
#                 transforms.Normalize(mean=(0.5, 0.5, 0.5),   # 3 for RGB channels
#                                      std=(0.5, 0.5, 0.5))])
transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.5],               # 1 for greyscale channels
                                     std=[0.5])])

# %%
# MNIST dataset
mnist = torchvision.datasets.MNIST(root='./data',
                                   train=True,
                                   transform=transform,
                                   download=True)

# %%
# Data loader
data_loader = torch.utils.data.DataLoader(dataset=mnist,
                                          batch_size=batch_size, 
                                          shuffle=True)

# %% [markdown]
# # 模型定义

# %% [markdown]
# ## 判别器定义

# %%
class Discriminator(nn.Module):
    def __init__(self, image_size: int, hidden_size: int):
        super(Discriminator, self).__init__()
        self.linear1 = nn.Linear(image_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out = self.linear1(x)
        out = F.leaky_relu(out, negative_slope=0.2, inplace=True)
        out = self.linear2(out)
        out = F.leaky_relu(out, negative_slope=0.2, inplace=True)
        out = self.linear3(out)
        return F.sigmoid(out)

# %%
# Discriminator
D = Discriminator(image_size=image_size, hidden_size=hidden_size)

# %% [markdown]
# ## 生成器定义

# %%
class Generator(nn.Module):
    def __init__(self, image_size: int, latent_size: int, hidden_size: int):
        super(Generator, self).__init__()
        self.linear1 = nn.Linear(latent_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, image_size)

    def forward(self, x):
        out = self.linear1(x)
        out = F.relu(out)
        out = self.linear2(out)
        out = F.relu(out)
        out = self.linear3(out)
        return F.tanh(out)

# %%
# Generator 
G = Generator(image_size=image_size, hidden_size=hidden_size, latent_size=latent_size)

# %%
# Device setting
D = D.to(device)
G = G.to(device)

# %% [markdown]
# # 模型训练

# %%
# Binary cross entropy loss and optimizer
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
# 图像反归一化
def denorm(x):
    min_value = -1
    max_value = 1
    out = (x - min_value) / (max_value - min_value)
    # plt expects values in [0, 1]
    return out.clamp(0, 1)

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

# %%
def train(D, G, data_loader, epoch):
    total_step = len(data_loader)
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
    for i, (images, _) in enumerate(data_loader):
        # ================================================================== #
        #                      Train the discriminator                       #
        # ================================================================== #
        # Compute BCE_Loss using real images where BCE_Loss(x, y): - y * log(D(x)) - (1 - y) * log(1 - D(x))
        # Second term of the loss is always zero since real_labels == 1
        real_images = images.reshape(batch_size, -1).to(device)
        d_outputs_real = D(real_images)
        d_loss_real = criterion(d_outputs_real, real_labels)
        real_score = d_outputs_real
        # Compute BCELoss using fake images
        # First term of the loss is always zero since fake_labels == 0
        z = torch.randn(batch_size, latent_size).to(device)
        fake_images = G(z)
        d_outputs_fake = D(fake_images)
        d_loss_fake = criterion(d_outputs_fake, fake_labels)
        fake_score = d_outputs_fake
        # Backprop and optimize
        d_loss = d_loss_real + d_loss_fake
        reset_grad()
        d_loss.backward()
        d_optimizer.step()
        # ================================================================== #
        #                        Train the generator                         #
        # ================================================================== #
        # Compute loss with fake images
        z = torch.randn(batch_size, latent_size).to(device)
        fake_images = G(z)
        d_outputs_fake = D(fake_images)
        # We train G to maximize log(D(G(z)) instead of minimizing log(1 - D(G(z)))
        # For the reason, see the last paragraph of section 3. https://arxiv.org/pdf/1406.2661.pdf
        g_loss = criterion(d_outputs_fake, real_labels)
        # Backprop and optimize
        reset_grad()
        g_loss.backward()
        g_optimizer.step()
        if (i + 1) % 200 == 0:
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i + 1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
    # Save real images
    if (epoch + 1) == 1:
        real_images = real_images.reshape(images.size(0), 1, 28, 28)
        real_images_name = 'real_images.png'
        save_image(denorm(real_images), os.path.join(image_dir, real_images_name))
        print('epoch {} real images {} saved'.format(epoch + 1, real_images_name))
    # Save fake images
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_images_name = 'fake_images-{}.png'.format(epoch+1)
    save_image(denorm(fake_images), os.path.join(image_dir, fake_images_name))
    print('epoch {} fake images {} saved'.format(epoch + 1, fake_images_name))

# %% [markdown]
# # 模型保存

# %%
def save_mode():
    # Save model
    torch.save(G.state_dict(), os.path.join(model_path, "Generator.pt"))
    torch.save(D.state_dict(), os.path.join(model_path, "Discriminator.pt"))
    print("models saved")

# %%
def main():
    # Start training
    for epoch in range(num_epochs):
        train(D, G, data_loader, epoch)
    save_mode()

# %%
if __name__ == '__main__':
    main()
# Out:
# Epoch [0/100], Step [200/600], d_loss: 0.0628, g_loss: 3.8714, D(x): 0.99, D(G(z)): 0.05
# Epoch [0/100], Step [400/600], d_loss: 0.0669, g_loss: 5.8127, D(x): 0.98, D(G(z)): 0.05
# Epoch [0/100], Step [600/600], d_loss: 0.0421, g_loss: 5.6172, D(x): 0.98, D(G(z)): 0.02
# epoch 1 real images real_images.png saved
# epoch 1 fake images fake_images-1.png saved
# Epoch [1/100], Step [200/600], d_loss: 0.0446, g_loss: 4.9776, D(x): 1.00, D(G(z)): 0.04
# Epoch [1/100], Step [400/600], d_loss: 0.0505, g_loss: 5.3517, D(x): 0.97, D(G(z)): 0.02
# Epoch [1/100], Step [600/600], d_loss: 0.5368, g_loss: 3.8375, D(x): 0.84, D(G(z)): 0.16
# epoch 2 fake images fake_images-2.png saved
# Epoch [2/100], Step [200/600], d_loss: 0.1171, g_loss: 3.8993, D(x): 0.96, D(G(z)): 0.05
# Epoch [2/100], Step [400/600], d_loss: 0.2336, g_loss: 5.0401, D(x): 0.91, D(G(z)): 0.05
# Epoch [2/100], Step [600/600], d_loss: 0.3689, g_loss: 4.0837, D(x): 0.86, D(G(z)): 0.07
# epoch 3 fake images fake_images-3.png saved
# Epoch [3/100], Step [200/600], d_loss: 0.2414, g_loss: 4.6569, D(x): 0.91, D(G(z)): 0.08
# Epoch [3/100], Step [400/600], d_loss: 0.5461, g_loss: 1.8418, D(x): 0.79, D(G(z)): 0.21
# Epoch [3/100], Step [600/600], d_loss: 0.5619, g_loss: 3.2620, D(x): 0.84, D(G(z)): 0.18
# epoch 4 fake images fake_images-4.png saved
# Epoch [4/100], Step [200/600], d_loss: 0.1622, g_loss: 4.6307, D(x): 0.94, D(G(z)): 0.08
# Epoch [4/100], Step [400/600], d_loss: 0.4043, g_loss: 2.9373, D(x): 0.84, D(G(z)): 0.10
# Epoch [4/100], Step [600/600], d_loss: 0.4986, g_loss: 2.3198, D(x): 0.79, D(G(z)): 0.12
# epoch 5 fake images fake_images-5.png saved
# Epoch [5/100], Step [200/600], d_loss: 0.4304, g_loss: 2.9098, D(x): 0.82, D(G(z)): 0.07
# Epoch [5/100], Step [400/600], d_loss: 0.3203, g_loss: 2.5428, D(x): 0.92, D(G(z)): 0.14
# Epoch [5/100], Step [600/600], d_loss: 0.2162, g_loss: 4.3447, D(x): 0.93, D(G(z)): 0.07
# epoch 6 fake images fake_images-6.png saved
# Epoch [6/100], Step [200/600], d_loss: 0.3914, g_loss: 3.6074, D(x): 0.91, D(G(z)): 0.11
# Epoch [6/100], Step [400/600], d_loss: 0.2534, g_loss: 4.1837, D(x): 0.91, D(G(z)): 0.05
# Epoch [6/100], Step [600/600], d_loss: 1.6452, g_loss: 1.9160, D(x): 0.77, D(G(z)): 0.55
# epoch 7 fake images fake_images-7.png saved
# Epoch [7/100], Step [200/600], d_loss: 0.1960, g_loss: 4.1152, D(x): 0.90, D(G(z)): 0.03
# Epoch [7/100], Step [400/600], d_loss: 0.5442, g_loss: 3.3370, D(x): 0.86, D(G(z)): 0.18
# Epoch [7/100], Step [600/600], d_loss: 0.1853, g_loss: 3.5940, D(x): 0.98, D(G(z)): 0.14
# epoch 8 fake images fake_images-8.png saved
# Epoch [8/100], Step [200/600], d_loss: 0.6992, g_loss: 3.6486, D(x): 0.84, D(G(z)): 0.20
# Epoch [8/100], Step [400/600], d_loss: 0.5741, g_loss: 2.0218, D(x): 0.89, D(G(z)): 0.23
# Epoch [8/100], Step [600/600], d_loss: 0.1509, g_loss: 4.3024, D(x): 0.96, D(G(z)): 0.05
# epoch 9 fake images fake_images-9.png saved
# Epoch [9/100], Step [200/600], d_loss: 0.0552, g_loss: 4.4921, D(x): 0.98, D(G(z)): 0.02
# Epoch [9/100], Step [400/600], d_loss: 0.1318, g_loss: 4.7554, D(x): 0.96, D(G(z)): 0.01
# Epoch [9/100], Step [600/600], d_loss: 0.1384, g_loss: 4.2969, D(x): 0.95, D(G(z)): 0.03
# epoch 10 fake images fake_images-10.png saved
# Epoch [10/100], Step [200/600], d_loss: 0.1000, g_loss: 5.6128, D(x): 0.97, D(G(z)): 0.05
# Epoch [10/100], Step [400/600], d_loss: 0.1064, g_loss: 6.4502, D(x): 0.99, D(G(z)): 0.07
# Epoch [10/100], Step [600/600], d_loss: 0.0686, g_loss: 5.4157, D(x): 0.98, D(G(z)): 0.03
# epoch 11 fake images fake_images-11.png saved
# Epoch [11/100], Step [200/600], d_loss: 0.1328, g_loss: 5.2524, D(x): 0.97, D(G(z)): 0.07
# Epoch [11/100], Step [400/600], d_loss: 0.0538, g_loss: 4.6965, D(x): 0.99, D(G(z)): 0.04
# Epoch [11/100], Step [600/600], d_loss: 0.0825, g_loss: 5.8009, D(x): 0.98, D(G(z)): 0.05
# epoch 12 fake images fake_images-12.png saved
# Epoch [12/100], Step [200/600], d_loss: 0.2184, g_loss: 6.0242, D(x): 0.96, D(G(z)): 0.02
# Epoch [12/100], Step [400/600], d_loss: 0.1133, g_loss: 4.2497, D(x): 0.98, D(G(z)): 0.06
# Epoch [12/100], Step [600/600], d_loss: 0.1400, g_loss: 5.1621, D(x): 0.97, D(G(z)): 0.05
# epoch 13 fake images fake_images-13.png saved
# Epoch [13/100], Step [200/600], d_loss: 0.1972, g_loss: 5.7065, D(x): 0.97, D(G(z)): 0.05
# Epoch [13/100], Step [400/600], d_loss: 0.3822, g_loss: 4.6160, D(x): 0.93, D(G(z)): 0.07
# Epoch [13/100], Step [600/600], d_loss: 0.0423, g_loss: 8.5629, D(x): 0.98, D(G(z)): 0.01
# epoch 14 fake images fake_images-14.png saved
# Epoch [14/100], Step [200/600], d_loss: 0.1975, g_loss: 4.6432, D(x): 0.94, D(G(z)): 0.01
# Epoch [14/100], Step [400/600], d_loss: 0.1937, g_loss: 3.8806, D(x): 0.98, D(G(z)): 0.12
# Epoch [14/100], Step [600/600], d_loss: 0.4286, g_loss: 4.2257, D(x): 0.85, D(G(z)): 0.03
# epoch 15 fake images fake_images-15.png saved
# Epoch [15/100], Step [200/600], d_loss: 0.1834, g_loss: 5.6453, D(x): 0.94, D(G(z)): 0.07
# Epoch [15/100], Step [400/600], d_loss: 0.0903, g_loss: 3.9300, D(x): 0.99, D(G(z)): 0.06
# Epoch [15/100], Step [600/600], d_loss: 0.3707, g_loss: 3.4142, D(x): 0.91, D(G(z)): 0.10
# epoch 16 fake images fake_images-16.png saved
# Epoch [16/100], Step [200/600], d_loss: 0.4800, g_loss: 6.2631, D(x): 0.92, D(G(z)): 0.16
# Epoch [16/100], Step [400/600], d_loss: 0.1834, g_loss: 4.1931, D(x): 0.95, D(G(z)): 0.05
# Epoch [16/100], Step [600/600], d_loss: 0.3414, g_loss: 3.8003, D(x): 0.92, D(G(z)): 0.13
# epoch 17 fake images fake_images-17.png saved
# Epoch [17/100], Step [200/600], d_loss: 0.2206, g_loss: 4.9103, D(x): 0.95, D(G(z)): 0.10
# Epoch [17/100], Step [400/600], d_loss: 0.7488, g_loss: 3.6120, D(x): 0.87, D(G(z)): 0.15
# Epoch [17/100], Step [600/600], d_loss: 0.4701, g_loss: 3.6395, D(x): 0.89, D(G(z)): 0.13
# epoch 18 fake images fake_images-18.png saved
# Epoch [18/100], Step [200/600], d_loss: 0.2170, g_loss: 4.3156, D(x): 0.94, D(G(z)): 0.06
# Epoch [18/100], Step [400/600], d_loss: 0.2384, g_loss: 2.8237, D(x): 0.96, D(G(z)): 0.12
# Epoch [18/100], Step [600/600], d_loss: 0.3940, g_loss: 2.8316, D(x): 0.92, D(G(z)): 0.16
# epoch 19 fake images fake_images-19.png saved
# Epoch [19/100], Step [200/600], d_loss: 0.4873, g_loss: 2.9946, D(x): 0.88, D(G(z)): 0.11
# Epoch [19/100], Step [400/600], d_loss: 0.3828, g_loss: 4.2648, D(x): 0.90, D(G(z)): 0.07
# Epoch [19/100], Step [600/600], d_loss: 0.3501, g_loss: 4.9269, D(x): 0.87, D(G(z)): 0.04
# epoch 20 fake images fake_images-20.png saved
# Epoch [20/100], Step [200/600], d_loss: 0.2488, g_loss: 4.7830, D(x): 0.95, D(G(z)): 0.13
# Epoch [20/100], Step [400/600], d_loss: 0.2483, g_loss: 3.9924, D(x): 0.93, D(G(z)): 0.06
# Epoch [20/100], Step [600/600], d_loss: 0.3382, g_loss: 3.4123, D(x): 0.92, D(G(z)): 0.07
# epoch 21 fake images fake_images-21.png saved
# Epoch [21/100], Step [200/600], d_loss: 0.1515, g_loss: 5.1302, D(x): 0.98, D(G(z)): 0.10
# Epoch [21/100], Step [400/600], d_loss: 0.4450, g_loss: 5.5724, D(x): 0.86, D(G(z)): 0.03
# Epoch [21/100], Step [600/600], d_loss: 0.3939, g_loss: 3.1867, D(x): 0.94, D(G(z)): 0.14
# epoch 22 fake images fake_images-22.png saved
# Epoch [22/100], Step [200/600], d_loss: 0.2160, g_loss: 4.4857, D(x): 0.95, D(G(z)): 0.07
# Epoch [22/100], Step [400/600], d_loss: 0.3116, g_loss: 4.4147, D(x): 0.91, D(G(z)): 0.04
# Epoch [22/100], Step [600/600], d_loss: 0.1865, g_loss: 4.4795, D(x): 0.95, D(G(z)): 0.06
# epoch 23 fake images fake_images-23.png saved
# Epoch [23/100], Step [200/600], d_loss: 0.2585, g_loss: 4.4562, D(x): 0.90, D(G(z)): 0.04
# Epoch [23/100], Step [400/600], d_loss: 0.1373, g_loss: 4.7002, D(x): 0.96, D(G(z)): 0.07
# Epoch [23/100], Step [600/600], d_loss: 0.1686, g_loss: 3.0816, D(x): 0.95, D(G(z)): 0.06
# epoch 24 fake images fake_images-24.png saved
# Epoch [24/100], Step [200/600], d_loss: 0.1469, g_loss: 5.0272, D(x): 0.95, D(G(z)): 0.05
# Epoch [24/100], Step [400/600], d_loss: 0.2257, g_loss: 3.7240, D(x): 0.92, D(G(z)): 0.08
# Epoch [24/100], Step [600/600], d_loss: 0.2359, g_loss: 4.0860, D(x): 0.92, D(G(z)): 0.07
# epoch 25 fake images fake_images-25.png saved
# Epoch [25/100], Step [200/600], d_loss: 0.2548, g_loss: 3.2321, D(x): 0.90, D(G(z)): 0.07
# Epoch [25/100], Step [400/600], d_loss: 0.4628, g_loss: 4.3744, D(x): 0.90, D(G(z)): 0.10
# Epoch [25/100], Step [600/600], d_loss: 0.5774, g_loss: 2.7479, D(x): 0.79, D(G(z)): 0.06
# epoch 26 fake images fake_images-26.png saved
# Epoch [26/100], Step [200/600], d_loss: 0.2731, g_loss: 3.6624, D(x): 0.91, D(G(z)): 0.05
# Epoch [26/100], Step [400/600], d_loss: 0.4028, g_loss: 2.6632, D(x): 0.91, D(G(z)): 0.13
# Epoch [26/100], Step [600/600], d_loss: 0.3954, g_loss: 3.4130, D(x): 0.90, D(G(z)): 0.14
# epoch 27 fake images fake_images-27.png saved
# Epoch [27/100], Step [200/600], d_loss: 0.2869, g_loss: 4.0192, D(x): 0.95, D(G(z)): 0.14
# Epoch [27/100], Step [400/600], d_loss: 0.4629, g_loss: 3.4173, D(x): 0.85, D(G(z)): 0.07
# Epoch [27/100], Step [600/600], d_loss: 0.3291, g_loss: 4.1727, D(x): 0.88, D(G(z)): 0.07
# epoch 28 fake images fake_images-28.png saved
# Epoch [28/100], Step [200/600], d_loss: 0.3024, g_loss: 4.2067, D(x): 0.89, D(G(z)): 0.07
# Epoch [28/100], Step [400/600], d_loss: 0.4753, g_loss: 3.8894, D(x): 0.80, D(G(z)): 0.05
# Epoch [28/100], Step [600/600], d_loss: 0.3455, g_loss: 2.5337, D(x): 0.87, D(G(z)): 0.08
# epoch 29 fake images fake_images-29.png saved
# Epoch [29/100], Step [200/600], d_loss: 0.4385, g_loss: 4.5991, D(x): 0.87, D(G(z)): 0.09
# Epoch [29/100], Step [400/600], d_loss: 0.3833, g_loss: 4.1842, D(x): 0.91, D(G(z)): 0.12
# Epoch [29/100], Step [600/600], d_loss: 0.3106, g_loss: 3.2146, D(x): 0.88, D(G(z)): 0.07
# epoch 30 fake images fake_images-30.png saved
# Epoch [30/100], Step [200/600], d_loss: 0.3836, g_loss: 3.6304, D(x): 0.87, D(G(z)): 0.09
# Epoch [30/100], Step [400/600], d_loss: 0.1905, g_loss: 4.0124, D(x): 0.96, D(G(z)): 0.10
# Epoch [30/100], Step [600/600], d_loss: 0.2024, g_loss: 4.6070, D(x): 0.94, D(G(z)): 0.08
# epoch 31 fake images fake_images-31.png saved
# Epoch [31/100], Step [200/600], d_loss: 0.2928, g_loss: 4.7099, D(x): 0.93, D(G(z)): 0.12
# Epoch [31/100], Step [400/600], d_loss: 0.5920, g_loss: 2.3464, D(x): 0.94, D(G(z)): 0.27
# Epoch [31/100], Step [600/600], d_loss: 0.3816, g_loss: 4.0246, D(x): 0.85, D(G(z)): 0.06
# epoch 32 fake images fake_images-32.png saved
# Epoch [32/100], Step [200/600], d_loss: 0.4346, g_loss: 3.3974, D(x): 0.96, D(G(z)): 0.25
# Epoch [32/100], Step [400/600], d_loss: 0.3614, g_loss: 3.0415, D(x): 0.90, D(G(z)): 0.13
# Epoch [32/100], Step [600/600], d_loss: 0.5135, g_loss: 4.4407, D(x): 0.80, D(G(z)): 0.04
# epoch 33 fake images fake_images-33.png saved
# Epoch [33/100], Step [200/600], d_loss: 0.8024, g_loss: 4.1113, D(x): 0.72, D(G(z)): 0.03
# Epoch [33/100], Step [400/600], d_loss: 0.5707, g_loss: 3.3452, D(x): 0.83, D(G(z)): 0.12
# Epoch [33/100], Step [600/600], d_loss: 0.2769, g_loss: 3.6744, D(x): 0.91, D(G(z)): 0.10
# epoch 34 fake images fake_images-34.png saved
# Epoch [34/100], Step [200/600], d_loss: 0.5324, g_loss: 3.0611, D(x): 0.86, D(G(z)): 0.18
# Epoch [34/100], Step [400/600], d_loss: 0.3587, g_loss: 4.2402, D(x): 0.92, D(G(z)): 0.13
# Epoch [34/100], Step [600/600], d_loss: 0.3113, g_loss: 5.1707, D(x): 0.86, D(G(z)): 0.05
# epoch 35 fake images fake_images-35.png saved
# Epoch [35/100], Step [200/600], d_loss: 0.6684, g_loss: 2.7415, D(x): 0.90, D(G(z)): 0.25
# Epoch [35/100], Step [400/600], d_loss: 0.4418, g_loss: 3.7379, D(x): 0.83, D(G(z)): 0.06
# Epoch [35/100], Step [600/600], d_loss: 0.3381, g_loss: 4.3077, D(x): 0.87, D(G(z)): 0.06
# epoch 36 fake images fake_images-36.png saved
# Epoch [36/100], Step [200/600], d_loss: 0.3791, g_loss: 2.9969, D(x): 0.87, D(G(z)): 0.11
# Epoch [36/100], Step [400/600], d_loss: 0.5405, g_loss: 2.7860, D(x): 0.85, D(G(z)): 0.20
# Epoch [36/100], Step [600/600], d_loss: 0.4427, g_loss: 5.1868, D(x): 0.80, D(G(z)): 0.02
# epoch 37 fake images fake_images-37.png saved
# Epoch [37/100], Step [200/600], d_loss: 0.5136, g_loss: 2.5528, D(x): 0.90, D(G(z)): 0.21
# Epoch [37/100], Step [400/600], d_loss: 0.6253, g_loss: 2.7756, D(x): 0.87, D(G(z)): 0.21
# Epoch [37/100], Step [600/600], d_loss: 0.3755, g_loss: 3.9488, D(x): 0.87, D(G(z)): 0.11
# epoch 38 fake images fake_images-38.png saved
# Epoch [38/100], Step [200/600], d_loss: 0.3108, g_loss: 3.4254, D(x): 0.89, D(G(z)): 0.11
# Epoch [38/100], Step [400/600], d_loss: 0.6252, g_loss: 3.1435, D(x): 0.78, D(G(z)): 0.11
# Epoch [38/100], Step [600/600], d_loss: 0.6364, g_loss: 2.9126, D(x): 0.76, D(G(z)): 0.10
# epoch 39 fake images fake_images-39.png saved
# Epoch [39/100], Step [200/600], d_loss: 0.4275, g_loss: 3.4267, D(x): 0.90, D(G(z)): 0.16
# Epoch [39/100], Step [400/600], d_loss: 0.5213, g_loss: 3.5278, D(x): 0.82, D(G(z)): 0.06
# Epoch [39/100], Step [600/600], d_loss: 0.5102, g_loss: 3.3320, D(x): 0.87, D(G(z)): 0.17
# epoch 40 fake images fake_images-40.png saved
# Epoch [40/100], Step [200/600], d_loss: 0.5782, g_loss: 1.8946, D(x): 0.89, D(G(z)): 0.25
# Epoch [40/100], Step [400/600], d_loss: 0.4781, g_loss: 2.9253, D(x): 0.84, D(G(z)): 0.16
# Epoch [40/100], Step [600/600], d_loss: 0.5573, g_loss: 2.4540, D(x): 0.86, D(G(z)): 0.21
# epoch 41 fake images fake_images-41.png saved
# Epoch [41/100], Step [200/600], d_loss: 0.6048, g_loss: 3.0944, D(x): 0.77, D(G(z)): 0.08
# Epoch [41/100], Step [400/600], d_loss: 0.7023, g_loss: 2.4571, D(x): 0.85, D(G(z)): 0.30
# Epoch [41/100], Step [600/600], d_loss: 0.5205, g_loss: 2.7296, D(x): 0.85, D(G(z)): 0.18
# epoch 42 fake images fake_images-42.png saved
# Epoch [42/100], Step [200/600], d_loss: 0.6886, g_loss: 2.3658, D(x): 0.77, D(G(z)): 0.13
# Epoch [42/100], Step [400/600], d_loss: 0.4663, g_loss: 2.9074, D(x): 0.87, D(G(z)): 0.19
# Epoch [42/100], Step [600/600], d_loss: 0.6597, g_loss: 2.6277, D(x): 0.82, D(G(z)): 0.23
# epoch 43 fake images fake_images-43.png saved
# Epoch [43/100], Step [200/600], d_loss: 0.3320, g_loss: 2.9698, D(x): 0.88, D(G(z)): 0.10
# Epoch [43/100], Step [400/600], d_loss: 0.7596, g_loss: 2.8029, D(x): 0.76, D(G(z)): 0.14
# Epoch [43/100], Step [600/600], d_loss: 0.5636, g_loss: 3.3604, D(x): 0.77, D(G(z)): 0.07
# epoch 44 fake images fake_images-44.png saved
# Epoch [44/100], Step [200/600], d_loss: 0.4804, g_loss: 2.3270, D(x): 0.87, D(G(z)): 0.20
# Epoch [44/100], Step [400/600], d_loss: 0.5903, g_loss: 2.9847, D(x): 0.83, D(G(z)): 0.20
# Epoch [44/100], Step [600/600], d_loss: 0.5151, g_loss: 2.5486, D(x): 0.83, D(G(z)): 0.14
# epoch 45 fake images fake_images-45.png saved
# Epoch [45/100], Step [200/600], d_loss: 0.5890, g_loss: 2.3146, D(x): 0.81, D(G(z)): 0.17
# Epoch [45/100], Step [400/600], d_loss: 0.5162, g_loss: 2.9500, D(x): 0.83, D(G(z)): 0.18
# Epoch [45/100], Step [600/600], d_loss: 0.5617, g_loss: 3.3379, D(x): 0.87, D(G(z)): 0.17
# epoch 46 fake images fake_images-46.png saved
# Epoch [46/100], Step [200/600], d_loss: 0.5432, g_loss: 2.1287, D(x): 0.85, D(G(z)): 0.19
# Epoch [46/100], Step [400/600], d_loss: 0.4945, g_loss: 2.2977, D(x): 0.83, D(G(z)): 0.11
# Epoch [46/100], Step [600/600], d_loss: 0.5548, g_loss: 2.5379, D(x): 0.85, D(G(z)): 0.20
# epoch 47 fake images fake_images-47.png saved
# Epoch [47/100], Step [200/600], d_loss: 0.4586, g_loss: 3.3193, D(x): 0.85, D(G(z)): 0.15
# Epoch [47/100], Step [400/600], d_loss: 0.4511, g_loss: 3.2572, D(x): 0.86, D(G(z)): 0.14
# Epoch [47/100], Step [600/600], d_loss: 0.4742, g_loss: 3.2530, D(x): 0.81, D(G(z)): 0.09
# epoch 48 fake images fake_images-48.png saved
# Epoch [48/100], Step [200/600], d_loss: 0.5507, g_loss: 2.1113, D(x): 0.86, D(G(z)): 0.19
# Epoch [48/100], Step [400/600], d_loss: 0.8756, g_loss: 3.2115, D(x): 0.72, D(G(z)): 0.15
# Epoch [48/100], Step [600/600], d_loss: 0.5236, g_loss: 3.0933, D(x): 0.81, D(G(z)): 0.14
# epoch 49 fake images fake_images-49.png saved
# Epoch [49/100], Step [200/600], d_loss: 0.6686, g_loss: 4.0013, D(x): 0.77, D(G(z)): 0.08
# Epoch [49/100], Step [400/600], d_loss: 0.3654, g_loss: 3.0152, D(x): 0.85, D(G(z)): 0.09
# Epoch [49/100], Step [600/600], d_loss: 0.4656, g_loss: 2.6071, D(x): 0.89, D(G(z)): 0.20
# epoch 50 fake images fake_images-50.png saved
# Epoch [50/100], Step [200/600], d_loss: 0.4735, g_loss: 3.3395, D(x): 0.85, D(G(z)): 0.16
# Epoch [50/100], Step [400/600], d_loss: 0.6453, g_loss: 3.3417, D(x): 0.80, D(G(z)): 0.22
# Epoch [50/100], Step [600/600], d_loss: 0.6226, g_loss: 2.3168, D(x): 0.77, D(G(z)): 0.11
# epoch 51 fake images fake_images-51.png saved
# Epoch [51/100], Step [200/600], d_loss: 0.5182, g_loss: 2.9168, D(x): 0.82, D(G(z)): 0.14
# Epoch [51/100], Step [400/600], d_loss: 0.4329, g_loss: 2.8078, D(x): 0.84, D(G(z)): 0.12
# Epoch [51/100], Step [600/600], d_loss: 0.7851, g_loss: 2.3686, D(x): 0.72, D(G(z)): 0.15
# epoch 52 fake images fake_images-52.png saved
# Epoch [52/100], Step [200/600], d_loss: 0.5899, g_loss: 2.2682, D(x): 0.80, D(G(z)): 0.16
# Epoch [52/100], Step [400/600], d_loss: 0.6105, g_loss: 2.9836, D(x): 0.83, D(G(z)): 0.23
# Epoch [52/100], Step [600/600], d_loss: 0.3809, g_loss: 2.5873, D(x): 0.89, D(G(z)): 0.18
# epoch 53 fake images fake_images-53.png saved
# Epoch [53/100], Step [200/600], d_loss: 0.5121, g_loss: 2.8134, D(x): 0.80, D(G(z)): 0.15
# Epoch [53/100], Step [400/600], d_loss: 0.5351, g_loss: 2.7458, D(x): 0.83, D(G(z)): 0.17
# Epoch [53/100], Step [600/600], d_loss: 0.5750, g_loss: 2.4581, D(x): 0.85, D(G(z)): 0.22
# epoch 54 fake images fake_images-54.png saved
# Epoch [54/100], Step [200/600], d_loss: 0.7642, g_loss: 2.3508, D(x): 0.74, D(G(z)): 0.20
# Epoch [54/100], Step [400/600], d_loss: 0.7025, g_loss: 2.4547, D(x): 0.88, D(G(z)): 0.33
# Epoch [54/100], Step [600/600], d_loss: 0.6391, g_loss: 2.6004, D(x): 0.80, D(G(z)): 0.21
# epoch 55 fake images fake_images-55.png saved
# Epoch [55/100], Step [200/600], d_loss: 0.6611, g_loss: 2.1927, D(x): 0.75, D(G(z)): 0.17
# Epoch [55/100], Step [400/600], d_loss: 0.5617, g_loss: 2.7992, D(x): 0.85, D(G(z)): 0.21
# Epoch [55/100], Step [600/600], d_loss: 0.6186, g_loss: 2.1907, D(x): 0.83, D(G(z)): 0.27
# epoch 56 fake images fake_images-56.png saved
# Epoch [56/100], Step [200/600], d_loss: 0.6050, g_loss: 2.2271, D(x): 0.86, D(G(z)): 0.23
# Epoch [56/100], Step [400/600], d_loss: 0.5269, g_loss: 2.3430, D(x): 0.84, D(G(z)): 0.18
# Epoch [56/100], Step [600/600], d_loss: 0.4326, g_loss: 2.6790, D(x): 0.83, D(G(z)): 0.13
# epoch 57 fake images fake_images-57.png saved
# Epoch [57/100], Step [200/600], d_loss: 0.4664, g_loss: 3.0406, D(x): 0.85, D(G(z)): 0.16
# Epoch [57/100], Step [400/600], d_loss: 0.7581, g_loss: 2.2835, D(x): 0.81, D(G(z)): 0.22
# Epoch [57/100], Step [600/600], d_loss: 0.5375, g_loss: 1.8504, D(x): 0.81, D(G(z)): 0.20
# epoch 58 fake images fake_images-58.png saved
# Epoch [58/100], Step [200/600], d_loss: 0.6652, g_loss: 2.4513, D(x): 0.87, D(G(z)): 0.33
# Epoch [58/100], Step [400/600], d_loss: 0.6544, g_loss: 3.0345, D(x): 0.78, D(G(z)): 0.14
# Epoch [58/100], Step [600/600], d_loss: 0.6649, g_loss: 2.2763, D(x): 0.79, D(G(z)): 0.18
# epoch 59 fake images fake_images-59.png saved
# Epoch [59/100], Step [200/600], d_loss: 0.4874, g_loss: 2.4871, D(x): 0.86, D(G(z)): 0.20
# Epoch [59/100], Step [400/600], d_loss: 0.5521, g_loss: 2.8662, D(x): 0.81, D(G(z)): 0.19
# Epoch [59/100], Step [600/600], d_loss: 0.4826, g_loss: 2.9998, D(x): 0.85, D(G(z)): 0.14
# epoch 60 fake images fake_images-60.png saved
# Epoch [60/100], Step [200/600], d_loss: 0.4544, g_loss: 2.6005, D(x): 0.82, D(G(z)): 0.11
# Epoch [60/100], Step [400/600], d_loss: 0.6546, g_loss: 2.9251, D(x): 0.80, D(G(z)): 0.20
# Epoch [60/100], Step [600/600], d_loss: 0.7257, g_loss: 2.8300, D(x): 0.75, D(G(z)): 0.15
# epoch 61 fake images fake_images-61.png saved
# Epoch [61/100], Step [200/600], d_loss: 0.5397, g_loss: 2.5850, D(x): 0.83, D(G(z)): 0.18
# Epoch [61/100], Step [400/600], d_loss: 0.5963, g_loss: 3.0775, D(x): 0.80, D(G(z)): 0.14
# Epoch [61/100], Step [600/600], d_loss: 0.7908, g_loss: 1.9951, D(x): 0.81, D(G(z)): 0.31
# epoch 62 fake images fake_images-62.png saved
# Epoch [62/100], Step [200/600], d_loss: 0.5880, g_loss: 2.9456, D(x): 0.81, D(G(z)): 0.19
# Epoch [62/100], Step [400/600], d_loss: 0.5759, g_loss: 2.4699, D(x): 0.86, D(G(z)): 0.27
# Epoch [62/100], Step [600/600], d_loss: 0.5300, g_loss: 3.1746, D(x): 0.82, D(G(z)): 0.17
# epoch 63 fake images fake_images-63.png saved
# Epoch [63/100], Step [200/600], d_loss: 0.7357, g_loss: 1.9840, D(x): 0.81, D(G(z)): 0.29
# Epoch [63/100], Step [400/600], d_loss: 0.6034, g_loss: 2.8669, D(x): 0.79, D(G(z)): 0.17
# Epoch [63/100], Step [600/600], d_loss: 0.6030, g_loss: 2.8989, D(x): 0.76, D(G(z)): 0.15
# epoch 64 fake images fake_images-64.png saved
# Epoch [64/100], Step [200/600], d_loss: 0.8945, g_loss: 2.2521, D(x): 0.76, D(G(z)): 0.25
# Epoch [64/100], Step [400/600], d_loss: 0.6637, g_loss: 2.2025, D(x): 0.86, D(G(z)): 0.27
# Epoch [64/100], Step [600/600], d_loss: 0.8149, g_loss: 2.5404, D(x): 0.77, D(G(z)): 0.24
# epoch 65 fake images fake_images-65.png saved
# Epoch [65/100], Step [200/600], d_loss: 0.5990, g_loss: 2.7068, D(x): 0.77, D(G(z)): 0.15
# Epoch [65/100], Step [400/600], d_loss: 0.5923, g_loss: 1.7969, D(x): 0.81, D(G(z)): 0.19
# Epoch [65/100], Step [600/600], d_loss: 0.5991, g_loss: 2.9945, D(x): 0.78, D(G(z)): 0.15
# epoch 66 fake images fake_images-66.png saved
# Epoch [66/100], Step [200/600], d_loss: 0.7590, g_loss: 2.7622, D(x): 0.80, D(G(z)): 0.29
# Epoch [66/100], Step [400/600], d_loss: 0.7754, g_loss: 1.6484, D(x): 0.75, D(G(z)): 0.22
# Epoch [66/100], Step [600/600], d_loss: 0.8256, g_loss: 2.3681, D(x): 0.68, D(G(z)): 0.18
# epoch 67 fake images fake_images-67.png saved
# Epoch [67/100], Step [200/600], d_loss: 0.5918, g_loss: 2.4488, D(x): 0.75, D(G(z)): 0.14
# Epoch [67/100], Step [400/600], d_loss: 1.0134, g_loss: 2.0035, D(x): 0.81, D(G(z)): 0.36
# Epoch [67/100], Step [600/600], d_loss: 0.5803, g_loss: 1.7104, D(x): 0.87, D(G(z)): 0.28
# epoch 68 fake images fake_images-68.png saved
# Epoch [68/100], Step [200/600], d_loss: 0.8166, g_loss: 2.3089, D(x): 0.80, D(G(z)): 0.32
# Epoch [68/100], Step [400/600], d_loss: 0.5211, g_loss: 2.0590, D(x): 0.79, D(G(z)): 0.14
# Epoch [68/100], Step [600/600], d_loss: 0.6071, g_loss: 2.3028, D(x): 0.78, D(G(z)): 0.23
# epoch 69 fake images fake_images-69.png saved
# Epoch [69/100], Step [200/600], d_loss: 0.7326, g_loss: 2.9739, D(x): 0.75, D(G(z)): 0.22
# Epoch [69/100], Step [400/600], d_loss: 0.6139, g_loss: 2.2619, D(x): 0.78, D(G(z)): 0.20
# Epoch [69/100], Step [600/600], d_loss: 0.6163, g_loss: 2.2153, D(x): 0.82, D(G(z)): 0.24
# epoch 70 fake images fake_images-70.png saved
# Epoch [70/100], Step [200/600], d_loss: 0.8356, g_loss: 1.7371, D(x): 0.80, D(G(z)): 0.34
# Epoch [70/100], Step [400/600], d_loss: 0.7451, g_loss: 2.6832, D(x): 0.74, D(G(z)): 0.24
# Epoch [70/100], Step [600/600], d_loss: 0.8020, g_loss: 1.7703, D(x): 0.81, D(G(z)): 0.32
# epoch 71 fake images fake_images-71.png saved
# Epoch [71/100], Step [200/600], d_loss: 0.5554, g_loss: 1.9481, D(x): 0.79, D(G(z)): 0.17
# Epoch [71/100], Step [400/600], d_loss: 0.5133, g_loss: 2.4780, D(x): 0.81, D(G(z)): 0.16
# Epoch [71/100], Step [600/600], d_loss: 0.6762, g_loss: 1.5547, D(x): 0.80, D(G(z)): 0.24
# epoch 72 fake images fake_images-72.png saved
# Epoch [72/100], Step [200/600], d_loss: 0.7398, g_loss: 1.9877, D(x): 0.75, D(G(z)): 0.19
# Epoch [72/100], Step [400/600], d_loss: 0.7395, g_loss: 2.3050, D(x): 0.73, D(G(z)): 0.20
# Epoch [72/100], Step [600/600], d_loss: 0.8111, g_loss: 2.3447, D(x): 0.68, D(G(z)): 0.19
# epoch 73 fake images fake_images-73.png saved
# Epoch [73/100], Step [200/600], d_loss: 0.6465, g_loss: 2.8202, D(x): 0.82, D(G(z)): 0.23
# Epoch [73/100], Step [400/600], d_loss: 0.8951, g_loss: 2.3123, D(x): 0.71, D(G(z)): 0.23
# Epoch [73/100], Step [600/600], d_loss: 0.7247, g_loss: 1.8527, D(x): 0.80, D(G(z)): 0.24
# epoch 74 fake images fake_images-74.png saved
# Epoch [74/100], Step [200/600], d_loss: 0.6348, g_loss: 2.2638, D(x): 0.74, D(G(z)): 0.13
# Epoch [74/100], Step [400/600], d_loss: 0.7320, g_loss: 2.0198, D(x): 0.79, D(G(z)): 0.24
# Epoch [74/100], Step [600/600], d_loss: 1.0097, g_loss: 1.5493, D(x): 0.68, D(G(z)): 0.27
# epoch 75 fake images fake_images-75.png saved
# Epoch [75/100], Step [200/600], d_loss: 0.7148, g_loss: 2.2493, D(x): 0.76, D(G(z)): 0.22
# Epoch [75/100], Step [400/600], d_loss: 0.6779, g_loss: 1.8527, D(x): 0.76, D(G(z)): 0.20
# Epoch [75/100], Step [600/600], d_loss: 0.8533, g_loss: 2.1577, D(x): 0.79, D(G(z)): 0.29
# epoch 76 fake images fake_images-76.png saved
# Epoch [76/100], Step [200/600], d_loss: 0.7061, g_loss: 2.7083, D(x): 0.76, D(G(z)): 0.21
# Epoch [76/100], Step [400/600], d_loss: 0.5570, g_loss: 2.5551, D(x): 0.83, D(G(z)): 0.21
# Epoch [76/100], Step [600/600], d_loss: 0.9727, g_loss: 1.1564, D(x): 0.73, D(G(z)): 0.29
# epoch 77 fake images fake_images-77.png saved
# Epoch [77/100], Step [200/600], d_loss: 0.7685, g_loss: 2.6213, D(x): 0.76, D(G(z)): 0.23
# Epoch [77/100], Step [400/600], d_loss: 0.7141, g_loss: 2.2154, D(x): 0.80, D(G(z)): 0.28
# Epoch [77/100], Step [600/600], d_loss: 0.7626, g_loss: 2.2072, D(x): 0.78, D(G(z)): 0.29
# epoch 78 fake images fake_images-78.png saved
# Epoch [78/100], Step [200/600], d_loss: 0.9301, g_loss: 1.8764, D(x): 0.69, D(G(z)): 0.26
# Epoch [78/100], Step [400/600], d_loss: 0.7286, g_loss: 2.0911, D(x): 0.78, D(G(z)): 0.26
# Epoch [78/100], Step [600/600], d_loss: 0.6974, g_loss: 2.2839, D(x): 0.78, D(G(z)): 0.23
# epoch 79 fake images fake_images-79.png saved
# Epoch [79/100], Step [200/600], d_loss: 0.7054, g_loss: 1.8713, D(x): 0.81, D(G(z)): 0.27
# Epoch [79/100], Step [400/600], d_loss: 0.8278, g_loss: 1.8259, D(x): 0.81, D(G(z)): 0.33
# Epoch [79/100], Step [600/600], d_loss: 0.5693, g_loss: 2.4804, D(x): 0.80, D(G(z)): 0.18
# epoch 80 fake images fake_images-80.png saved
# Epoch [80/100], Step [200/600], d_loss: 0.6281, g_loss: 2.7847, D(x): 0.81, D(G(z)): 0.20
# Epoch [80/100], Step [400/600], d_loss: 0.5349, g_loss: 2.3089, D(x): 0.78, D(G(z)): 0.15
# Epoch [80/100], Step [600/600], d_loss: 0.6571, g_loss: 2.1152, D(x): 0.76, D(G(z)): 0.19
# epoch 81 fake images fake_images-81.png saved
# Epoch [81/100], Step [200/600], d_loss: 0.5805, g_loss: 2.0438, D(x): 0.79, D(G(z)): 0.18
# Epoch [81/100], Step [400/600], d_loss: 0.8077, g_loss: 2.9320, D(x): 0.83, D(G(z)): 0.31
# Epoch [81/100], Step [600/600], d_loss: 0.7610, g_loss: 2.1547, D(x): 0.80, D(G(z)): 0.28
# epoch 82 fake images fake_images-82.png saved
# Epoch [82/100], Step [200/600], d_loss: 0.6015, g_loss: 2.5558, D(x): 0.89, D(G(z)): 0.29
# Epoch [82/100], Step [400/600], d_loss: 0.4603, g_loss: 2.2596, D(x): 0.86, D(G(z)): 0.20
# Epoch [82/100], Step [600/600], d_loss: 0.8620, g_loss: 2.1922, D(x): 0.67, D(G(z)): 0.20
# epoch 83 fake images fake_images-83.png saved
# Epoch [83/100], Step [200/600], d_loss: 0.7932, g_loss: 2.3365, D(x): 0.84, D(G(z)): 0.32
# Epoch [83/100], Step [400/600], d_loss: 0.7775, g_loss: 2.3291, D(x): 0.70, D(G(z)): 0.17
# Epoch [83/100], Step [600/600], d_loss: 0.7804, g_loss: 1.5735, D(x): 0.76, D(G(z)): 0.24
# epoch 84 fake images fake_images-84.png saved
# Epoch [84/100], Step [200/600], d_loss: 0.6611, g_loss: 1.7120, D(x): 0.87, D(G(z)): 0.32
# Epoch [84/100], Step [400/600], d_loss: 0.6705, g_loss: 2.1119, D(x): 0.78, D(G(z)): 0.22
# Epoch [84/100], Step [600/600], d_loss: 0.6744, g_loss: 2.1931, D(x): 0.78, D(G(z)): 0.22
# epoch 85 fake images fake_images-85.png saved
# Epoch [85/100], Step [200/600], d_loss: 0.6485, g_loss: 2.5030, D(x): 0.76, D(G(z)): 0.19
# Epoch [85/100], Step [400/600], d_loss: 0.7404, g_loss: 1.6754, D(x): 0.76, D(G(z)): 0.25
# Epoch [85/100], Step [600/600], d_loss: 0.8493, g_loss: 2.1316, D(x): 0.72, D(G(z)): 0.23
# epoch 86 fake images fake_images-86.png saved
# Epoch [86/100], Step [200/600], d_loss: 0.7692, g_loss: 1.6286, D(x): 0.77, D(G(z)): 0.25
# Epoch [86/100], Step [400/600], d_loss: 0.7710, g_loss: 2.5002, D(x): 0.72, D(G(z)): 0.18
# Epoch [86/100], Step [600/600], d_loss: 0.7520, g_loss: 1.5299, D(x): 0.73, D(G(z)): 0.23
# epoch 87 fake images fake_images-87.png saved
# Epoch [87/100], Step [200/600], d_loss: 0.5510, g_loss: 2.0775, D(x): 0.81, D(G(z)): 0.19
# Epoch [87/100], Step [400/600], d_loss: 0.6217, g_loss: 2.1142, D(x): 0.82, D(G(z)): 0.25
# Epoch [87/100], Step [600/600], d_loss: 0.4992, g_loss: 2.4488, D(x): 0.82, D(G(z)): 0.20
# epoch 88 fake images fake_images-88.png saved
# Epoch [88/100], Step [200/600], d_loss: 0.7248, g_loss: 2.0439, D(x): 0.75, D(G(z)): 0.21
# Epoch [88/100], Step [400/600], d_loss: 0.6274, g_loss: 2.1503, D(x): 0.80, D(G(z)): 0.21
# Epoch [88/100], Step [600/600], d_loss: 0.9272, g_loss: 1.5381, D(x): 0.67, D(G(z)): 0.23
# epoch 89 fake images fake_images-89.png saved
# Epoch [89/100], Step [200/600], d_loss: 0.6585, g_loss: 1.6902, D(x): 0.81, D(G(z)): 0.25
# Epoch [89/100], Step [400/600], d_loss: 0.7272, g_loss: 2.5151, D(x): 0.78, D(G(z)): 0.27
# Epoch [89/100], Step [600/600], d_loss: 0.6641, g_loss: 2.7452, D(x): 0.78, D(G(z)): 0.23
# epoch 90 fake images fake_images-90.png saved
# Epoch [90/100], Step [200/600], d_loss: 0.7389, g_loss: 1.6645, D(x): 0.79, D(G(z)): 0.27
# Epoch [90/100], Step [400/600], d_loss: 0.6289, g_loss: 2.5180, D(x): 0.75, D(G(z)): 0.15
# Epoch [90/100], Step [600/600], d_loss: 0.8140, g_loss: 2.5909, D(x): 0.71, D(G(z)): 0.21
# epoch 91 fake images fake_images-91.png saved
# Epoch [91/100], Step [200/600], d_loss: 0.9781, g_loss: 1.9103, D(x): 0.60, D(G(z)): 0.15
# Epoch [91/100], Step [400/600], d_loss: 0.8554, g_loss: 2.1022, D(x): 0.75, D(G(z)): 0.29
# Epoch [91/100], Step [600/600], d_loss: 0.6801, g_loss: 2.0613, D(x): 0.80, D(G(z)): 0.26
# epoch 92 fake images fake_images-92.png saved
# Epoch [92/100], Step [200/600], d_loss: 0.9077, g_loss: 2.0457, D(x): 0.75, D(G(z)): 0.32
# Epoch [92/100], Step [400/600], d_loss: 0.9382, g_loss: 1.6109, D(x): 0.72, D(G(z)): 0.30
# Epoch [92/100], Step [600/600], d_loss: 0.9223, g_loss: 1.6926, D(x): 0.68, D(G(z)): 0.23
# epoch 93 fake images fake_images-93.png saved
# Epoch [93/100], Step [200/600], d_loss: 0.8914, g_loss: 1.7847, D(x): 0.75, D(G(z)): 0.32
# Epoch [93/100], Step [400/600], d_loss: 0.6330, g_loss: 2.0675, D(x): 0.80, D(G(z)): 0.26
# Epoch [93/100], Step [600/600], d_loss: 0.7046, g_loss: 2.0568, D(x): 0.77, D(G(z)): 0.23
# epoch 94 fake images fake_images-94.png saved
# Epoch [94/100], Step [200/600], d_loss: 0.8731, g_loss: 1.8513, D(x): 0.75, D(G(z)): 0.33
# Epoch [94/100], Step [400/600], d_loss: 0.7255, g_loss: 2.2690, D(x): 0.81, D(G(z)): 0.29
# Epoch [94/100], Step [600/600], d_loss: 1.0450, g_loss: 1.6731, D(x): 0.68, D(G(z)): 0.31
# epoch 95 fake images fake_images-95.png saved
# Epoch [95/100], Step [200/600], d_loss: 0.6965, g_loss: 2.2197, D(x): 0.78, D(G(z)): 0.25
# Epoch [95/100], Step [400/600], d_loss: 0.7680, g_loss: 1.5910, D(x): 0.73, D(G(z)): 0.23
# Epoch [95/100], Step [600/600], d_loss: 0.9305, g_loss: 1.7406, D(x): 0.83, D(G(z)): 0.41
# epoch 96 fake images fake_images-96.png saved
# Epoch [96/100], Step [200/600], d_loss: 0.8309, g_loss: 1.7481, D(x): 0.80, D(G(z)): 0.29
# Epoch [96/100], Step [400/600], d_loss: 0.7233, g_loss: 2.0532, D(x): 0.75, D(G(z)): 0.21
# Epoch [96/100], Step [600/600], d_loss: 0.7552, g_loss: 1.7015, D(x): 0.78, D(G(z)): 0.27
# epoch 97 fake images fake_images-97.png saved
# Epoch [97/100], Step [200/600], d_loss: 0.6900, g_loss: 1.9398, D(x): 0.74, D(G(z)): 0.20
# Epoch [97/100], Step [400/600], d_loss: 0.9892, g_loss: 1.5774, D(x): 0.63, D(G(z)): 0.23
# Epoch [97/100], Step [600/600], d_loss: 0.8391, g_loss: 2.0760, D(x): 0.66, D(G(z)): 0.19
# epoch 98 fake images fake_images-98.png saved
# Epoch [98/100], Step [200/600], d_loss: 0.7356, g_loss: 2.2324, D(x): 0.79, D(G(z)): 0.28
# Epoch [98/100], Step [400/600], d_loss: 0.8052, g_loss: 1.7887, D(x): 0.79, D(G(z)): 0.31
# Epoch [98/100], Step [600/600], d_loss: 0.9994, g_loss: 1.5736, D(x): 0.75, D(G(z)): 0.36
# epoch 99 fake images fake_images-99.png saved
# Epoch [99/100], Step [200/600], d_loss: 0.8006, g_loss: 1.7276, D(x): 0.72, D(G(z)): 0.26
# Epoch [99/100], Step [400/600], d_loss: 0.8622, g_loss: 1.8816, D(x): 0.68, D(G(z)): 0.20
# Epoch [99/100], Step [600/600], d_loss: 0.5415, g_loss: 2.4284, D(x): 0.81, D(G(z)): 0.20
# epoch 100 fake images fake_images-100.png saved
# models saved
# Epoch [61/100], Step [400/600], d_loss: 0.6660, g_loss: 1.5530, D(x): 0.87, D(G(z)): 0.33
# Epoch [61/100], Step [600/600], d_loss: 0.5907, g_loss: 2.4484, D(x): 0.84, D(G(z)): 0.21
# Epoch [62/100], Step [200/600], d_loss: 0.3851, g_loss: 2.8583, D(x): 0.91, D(G(z)): 0.19
# Epoch [62/100], Step [400/600], d_loss: 0.4070, g_loss: 2.8479, D(x): 0.85, D(G(z)): 0.14
# Epoch [62/100], Step [600/600], d_loss: 0.7081, g_loss: 3.2311, D(x): 0.93, D(G(z)): 0.33
# Epoch [63/100], Step [200/600], d_loss: 0.5276, g_loss: 2.6238, D(x): 0.81, D(G(z)): 0.14
# Epoch [63/100], Step [400/600], d_loss: 0.5914, g_loss: 3.0684, D(x): 0.83, D(G(z)): 0.24
# Epoch [63/100], Step [600/600], d_loss: 0.5139, g_loss: 2.2964, D(x): 0.84, D(G(z)): 0.19
# Epoch [64/100], Step [200/600], d_loss: 0.6675, g_loss: 2.5774, D(x): 0.75, D(G(z)): 0.14
# Epoch [64/100], Step [400/600], d_loss: 0.7898, g_loss: 2.6074, D(x): 0.70, D(G(z)): 0.17
# Epoch [64/100], Step [600/600], d_loss: 0.7838, g_loss: 2.6269, D(x): 0.75, D(G(z)): 0.17
# Epoch [65/100], Step [200/600], d_loss: 0.7285, g_loss: 1.9271, D(x): 0.81, D(G(z)): 0.29
# Epoch [65/100], Step [400/600], d_loss: 0.6328, g_loss: 2.1047, D(x): 0.85, D(G(z)): 0.26
# Epoch [65/100], Step [600/600], d_loss: 0.7592, g_loss: 1.7595, D(x): 0.72, D(G(z)): 0.18
# Epoch [66/100], Step [200/600], d_loss: 0.6752, g_loss: 1.6024, D(x): 0.88, D(G(z)): 0.34
# Epoch [66/100], Step [400/600], d_loss: 0.5245, g_loss: 2.2016, D(x): 0.83, D(G(z)): 0.19
# Epoch [66/100], Step [600/600], d_loss: 0.5600, g_loss: 1.9574, D(x): 0.79, D(G(z)): 0.18
# Epoch [67/100], Step [200/600], d_loss: 0.7799, g_loss: 2.5870, D(x): 0.71, D(G(z)): 0.19
# Epoch [67/100], Step [400/600], d_loss: 0.8082, g_loss: 2.6109, D(x): 0.71, D(G(z)): 0.17
# Epoch [67/100], Step [600/600], d_loss: 0.6933, g_loss: 1.8820, D(x): 0.77, D(G(z)): 0.21
# Epoch [68/100], Step [200/600], d_loss: 0.6585, g_loss: 2.4271, D(x): 0.82, D(G(z)): 0.24
# Epoch [68/100], Step [400/600], d_loss: 0.7711, g_loss: 2.7206, D(x): 0.76, D(G(z)): 0.24
# Epoch [68/100], Step [600/600], d_loss: 0.5772, g_loss: 2.6272, D(x): 0.80, D(G(z)): 0.17
# Epoch [69/100], Step [200/600], d_loss: 0.6341, g_loss: 3.0444, D(x): 0.84, D(G(z)): 0.25
# Epoch [69/100], Step [400/600], d_loss: 0.6788, g_loss: 2.1254, D(x): 0.73, D(G(z)): 0.14
# Epoch [69/100], Step [600/600], d_loss: 0.7334, g_loss: 2.7484, D(x): 0.70, D(G(z)): 0.13
# Epoch [70/100], Step [200/600], d_loss: 0.8855, g_loss: 1.2968, D(x): 0.66, D(G(z)): 0.22
# Epoch [70/100], Step [400/600], d_loss: 0.7497, g_loss: 2.8778, D(x): 0.73, D(G(z)): 0.23
# Epoch [70/100], Step [600/600], d_loss: 0.6071, g_loss: 2.6094, D(x): 0.77, D(G(z)): 0.19
# Epoch [71/100], Step [200/600], d_loss: 0.5607, g_loss: 2.3791, D(x): 0.77, D(G(z)): 0.13
# Epoch [71/100], Step [400/600], d_loss: 0.6724, g_loss: 1.8600, D(x): 0.83, D(G(z)): 0.30
# Epoch [71/100], Step [600/600], d_loss: 0.7786, g_loss: 2.2528, D(x): 0.77, D(G(z)): 0.24
# Epoch [72/100], Step [200/600], d_loss: 0.6980, g_loss: 2.2038, D(x): 0.83, D(G(z)): 0.28
# Epoch [72/100], Step [400/600], d_loss: 0.7583, g_loss: 2.0547, D(x): 0.70, D(G(z)): 0.16
# Epoch [72/100], Step [600/600], d_loss: 0.5086, g_loss: 2.4252, D(x): 0.87, D(G(z)): 0.24
# Epoch [73/100], Step [200/600], d_loss: 0.8762, g_loss: 2.3244, D(x): 0.66, D(G(z)): 0.22
# Epoch [73/100], Step [400/600], d_loss: 0.6003, g_loss: 2.0457, D(x): 0.80, D(G(z)): 0.21
# Epoch [73/100], Step [600/600], d_loss: 0.6621, g_loss: 2.5636, D(x): 0.71, D(G(z)): 0.13
# Epoch [74/100], Step [200/600], d_loss: 0.5960, g_loss: 2.0722, D(x): 0.79, D(G(z)): 0.20
# Epoch [74/100], Step [400/600], d_loss: 0.6069, g_loss: 2.3214, D(x): 0.80, D(G(z)): 0.19
# Epoch [74/100], Step [600/600], d_loss: 0.5527, g_loss: 2.4206, D(x): 0.80, D(G(z)): 0.16
# Epoch [75/100], Step [200/600], d_loss: 0.6236, g_loss: 2.3964, D(x): 0.78, D(G(z)): 0.18
# Epoch [75/100], Step [400/600], d_loss: 0.8063, g_loss: 2.0070, D(x): 0.79, D(G(z)): 0.30
# Epoch [75/100], Step [600/600], d_loss: 0.4693, g_loss: 2.9839, D(x): 0.85, D(G(z)): 0.20
# Epoch [76/100], Step [200/600], d_loss: 0.5504, g_loss: 2.7548, D(x): 0.85, D(G(z)): 0.21
# Epoch [76/100], Step [400/600], d_loss: 0.7809, g_loss: 1.8751, D(x): 0.76, D(G(z)): 0.25
# Epoch [76/100], Step [600/600], d_loss: 0.6638, g_loss: 2.8172, D(x): 0.77, D(G(z)): 0.21
# Epoch [77/100], Step [200/600], d_loss: 0.6309, g_loss: 2.4472, D(x): 0.77, D(G(z)): 0.19
# Epoch [77/100], Step [400/600], d_loss: 0.8938, g_loss: 2.6745, D(x): 0.68, D(G(z)): 0.14
# Epoch [77/100], Step [600/600], d_loss: 0.7275, g_loss: 2.2666, D(x): 0.81, D(G(z)): 0.29
# Epoch [78/100], Step [200/600], d_loss: 0.7750, g_loss: 1.7481, D(x): 0.75, D(G(z)): 0.23
# Epoch [78/100], Step [400/600], d_loss: 0.5700, g_loss: 2.6878, D(x): 0.82, D(G(z)): 0.21
# Epoch [78/100], Step [600/600], d_loss: 0.7005, g_loss: 2.4878, D(x): 0.69, D(G(z)): 0.13
# Epoch [79/100], Step [200/600], d_loss: 0.5612, g_loss: 2.5973, D(x): 0.81, D(G(z)): 0.19
# Epoch [79/100], Step [400/600], d_loss: 0.6548, g_loss: 2.2643, D(x): 0.82, D(G(z)): 0.25
# Epoch [79/100], Step [600/600], d_loss: 0.6172, g_loss: 2.1422, D(x): 0.77, D(G(z)): 0.21
# Epoch [80/100], Step [200/600], d_loss: 0.7136, g_loss: 1.9797, D(x): 0.79, D(G(z)): 0.26
# Epoch [80/100], Step [400/600], d_loss: 0.8033, g_loss: 1.9992, D(x): 0.85, D(G(z)): 0.33
# Epoch [80/100], Step [600/600], d_loss: 0.5248, g_loss: 2.4785, D(x): 0.84, D(G(z)): 0.22
# Epoch [81/100], Step [200/600], d_loss: 1.0529, g_loss: 1.9395, D(x): 0.77, D(G(z)): 0.36
# Epoch [81/100], Step [400/600], d_loss: 0.5709, g_loss: 1.9054, D(x): 0.77, D(G(z)): 0.17
# Epoch [81/100], Step [600/600], d_loss: 0.7508, g_loss: 1.9965, D(x): 0.69, D(G(z)): 0.20
# Epoch [82/100], Step [200/600], d_loss: 0.8547, g_loss: 2.0162, D(x): 0.68, D(G(z)): 0.18
# Epoch [82/100], Step [400/600], d_loss: 0.6927, g_loss: 2.2364, D(x): 0.81, D(G(z)): 0.26
# Epoch [82/100], Step [600/600], d_loss: 0.8686, g_loss: 2.3457, D(x): 0.67, D(G(z)): 0.15
# Epoch [83/100], Step [200/600], d_loss: 0.5593, g_loss: 2.3122, D(x): 0.83, D(G(z)): 0.21
# Epoch [83/100], Step [400/600], d_loss: 0.9513, g_loss: 1.7334, D(x): 0.69, D(G(z)): 0.25
# Epoch [83/100], Step [600/600], d_loss: 0.8697, g_loss: 1.8475, D(x): 0.71, D(G(z)): 0.23
# Epoch [84/100], Step [200/600], d_loss: 0.7374, g_loss: 2.7667, D(x): 0.76, D(G(z)): 0.23
# Epoch [84/100], Step [400/600], d_loss: 0.7469, g_loss: 2.0681, D(x): 0.82, D(G(z)): 0.30
# Epoch [84/100], Step [600/600], d_loss: 0.4979, g_loss: 2.6522, D(x): 0.82, D(G(z)): 0.17
# Epoch [85/100], Step [200/600], d_loss: 0.7346, g_loss: 2.3775, D(x): 0.76, D(G(z)): 0.23
# Epoch [85/100], Step [400/600], d_loss: 0.6957, g_loss: 2.1110, D(x): 0.79, D(G(z)): 0.26
# Epoch [85/100], Step [600/600], d_loss: 0.7689, g_loss: 2.0882, D(x): 0.73, D(G(z)): 0.21
# Epoch [86/100], Step [200/600], d_loss: 0.7028, g_loss: 2.0618, D(x): 0.83, D(G(z)): 0.32
# Epoch [86/100], Step [400/600], d_loss: 0.7288, g_loss: 2.0085, D(x): 0.85, D(G(z)): 0.33
# Epoch [86/100], Step [600/600], d_loss: 0.6630, g_loss: 2.2668, D(x): 0.82, D(G(z)): 0.25
# Epoch [87/100], Step [200/600], d_loss: 0.7925, g_loss: 1.8939, D(x): 0.74, D(G(z)): 0.22
# Epoch [87/100], Step [400/600], d_loss: 0.8934, g_loss: 1.6368, D(x): 0.67, D(G(z)): 0.22
# Epoch [87/100], Step [600/600], d_loss: 0.7586, g_loss: 2.4203, D(x): 0.76, D(G(z)): 0.24
# Epoch [88/100], Step [200/600], d_loss: 0.7998, g_loss: 1.9826, D(x): 0.75, D(G(z)): 0.26
# Epoch [88/100], Step [400/600], d_loss: 0.8768, g_loss: 2.0291, D(x): 0.67, D(G(z)): 0.19
# Epoch [88/100], Step [600/600], d_loss: 0.8469, g_loss: 2.2006, D(x): 0.72, D(G(z)): 0.22
# Epoch [89/100], Step [200/600], d_loss: 0.6976, g_loss: 2.0712, D(x): 0.75, D(G(z)): 0.22
# Epoch [89/100], Step [400/600], d_loss: 0.9456, g_loss: 1.4515, D(x): 0.74, D(G(z)): 0.34
# Epoch [89/100], Step [600/600], d_loss: 0.6612, g_loss: 1.8810, D(x): 0.84, D(G(z)): 0.29
# Epoch [90/100], Step [200/600], d_loss: 0.7109, g_loss: 1.7360, D(x): 0.86, D(G(z)): 0.32
# Epoch [90/100], Step [400/600], d_loss: 0.7905, g_loss: 2.3313, D(x): 0.71, D(G(z)): 0.20
# Epoch [90/100], Step [600/600], d_loss: 0.8020, g_loss: 1.6160, D(x): 0.75, D(G(z)): 0.26
# Epoch [91/100], Step [200/600], d_loss: 0.6623, g_loss: 2.0016, D(x): 0.76, D(G(z)): 0.21
# Epoch [91/100], Step [400/600], d_loss: 0.8336, g_loss: 1.7240, D(x): 0.79, D(G(z)): 0.29
# Epoch [91/100], Step [600/600], d_loss: 0.9612, g_loss: 1.8934, D(x): 0.67, D(G(z)): 0.26
# Epoch [92/100], Step [200/600], d_loss: 0.8001, g_loss: 1.6516, D(x): 0.71, D(G(z)): 0.25
# Epoch [92/100], Step [400/600], d_loss: 0.6889, g_loss: 2.2359, D(x): 0.77, D(G(z)): 0.24
# Epoch [92/100], Step [600/600], d_loss: 0.6726, g_loss: 1.6754, D(x): 0.81, D(G(z)): 0.27
# Epoch [93/100], Step [200/600], d_loss: 0.7507, g_loss: 2.0496, D(x): 0.71, D(G(z)): 0.19
# Epoch [93/100], Step [400/600], d_loss: 0.7378, g_loss: 2.1993, D(x): 0.77, D(G(z)): 0.25
# Epoch [93/100], Step [600/600], d_loss: 0.8526, g_loss: 2.5157, D(x): 0.70, D(G(z)): 0.23
# Epoch [94/100], Step [200/600], d_loss: 0.8022, g_loss: 1.8209, D(x): 0.75, D(G(z)): 0.25
# Epoch [94/100], Step [400/600], d_loss: 0.8231, g_loss: 1.4436, D(x): 0.79, D(G(z)): 0.32
# Epoch [94/100], Step [600/600], d_loss: 0.7198, g_loss: 1.7707, D(x): 0.77, D(G(z)): 0.25
# Epoch [95/100], Step [200/600], d_loss: 1.0768, g_loss: 1.4693, D(x): 0.68, D(G(z)): 0.28
# Epoch [95/100], Step [400/600], d_loss: 0.9034, g_loss: 1.7187, D(x): 0.67, D(G(z)): 0.26
# Epoch [95/100], Step [600/600], d_loss: 0.5372, g_loss: 1.9625, D(x): 0.83, D(G(z)): 0.21
# Epoch [96/100], Step [200/600], d_loss: 0.9078, g_loss: 2.1554, D(x): 0.68, D(G(z)): 0.26
# Epoch [96/100], Step [400/600], d_loss: 0.7907, g_loss: 2.1369, D(x): 0.72, D(G(z)): 0.20
# Epoch [96/100], Step [600/600], d_loss: 0.7191, g_loss: 1.7693, D(x): 0.79, D(G(z)): 0.27
# Epoch [97/100], Step [200/600], d_loss: 0.8261, g_loss: 1.6517, D(x): 0.74, D(G(z)): 0.28
# Epoch [97/100], Step [400/600], d_loss: 0.6511, g_loss: 2.9203, D(x): 0.78, D(G(z)): 0.22
# Epoch [97/100], Step [600/600], d_loss: 0.7000, g_loss: 1.8859, D(x): 0.77, D(G(z)): 0.25
# Epoch [98/100], Step [200/600], d_loss: 0.9703, g_loss: 1.5161, D(x): 0.74, D(G(z)): 0.31
# Epoch [98/100], Step [400/600], d_loss: 1.0045, g_loss: 1.4213, D(x): 0.83, D(G(z)): 0.40
# Epoch [98/100], Step [600/600], d_loss: 0.8440, g_loss: 1.7508, D(x): 0.75, D(G(z)): 0.28
# Epoch [99/100], Step [200/600], d_loss: 0.7203, g_loss: 1.7188, D(x): 0.77, D(G(z)): 0.23
# Epoch [99/100], Step [400/600], d_loss: 0.8527, g_loss: 1.6463, D(x): 0.67, D(G(z)): 0.23
# Epoch [99/100], Step [600/600], d_loss: 1.0424, g_loss: 1.7350, D(x): 0.69, D(G(z)): 0.32
# model checkpoints saved
