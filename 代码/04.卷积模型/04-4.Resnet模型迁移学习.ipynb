# %%
import import_ipynb
import os
import random
import csv
from PIL import Image
import torch
from torch import optim
from torch import nn
import torchvision
from torchvision import transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision.models import resnet18

# %% [markdown]
# # Pokemon类定义

# %%
class Pokemon(Dataset):
    def __init__(self, root, resize, mode):
        super(Pokemon, self).__init__()
        self.root = root
        self.resize = resize
        self.name2label = {}
        for name in sorted(os.listdir(os.path.join(root))):
            if not os.path.isdir(os.path.join(root, name)):
                continue
            self.name2label[name] = len(self.name2label.keys())
        print(self.name2label)
        # image, label
        self.images, self.labels = self.load_csv('images.csv')
        if mode == 'train':  # 60%
            self.images = self.images[: int(0.6 * len(self.images))]
            self.labels = self.labels[: int(0.6 * len(self.labels))]
        elif mode == 'val':  # 20% = 60% -> 80%
            self.images = self.images[int(0.6 * len(self.images)): int(0.8 * len(self.images))]
            self.labels = self.labels[int(0.6 * len(self.labels)): int(0.8 * len(self.labels))]
        else:  # 20% = 80% -> 100%
            self.images = self.images[int(0.8 * len(self.images)):]
            self.labels = self.labels[int(0.8 * len(self.labels)):]

    # 加载csv
    def load_csv(self, filename):
        if not os.path.exists(os.path.join(self.root, filename)):
            images = []
            for name in self.name2label.keys():
                # 'pokemon\\mewtwo\\00001.png
                images += glob.glob(os.path.join(self.root, name, '*.png'))
                images += glob.glob(os.path.join(self.root, name, '*.jpg'))
                images += glob.glob(os.path.join(self.root, name, '*.jpeg'))
            # 1167, 'pokemon\\bulbasaur\\00000000.png'
            # print(len(images), images)
            random.shuffle(images)
            with open(os.path.join(self.root, filename), mode='w', newline='') as f:
                writer = csv.writer(f)
                for img in images:  # 'pokemon\\bulbasaur\\00000000.png'
                    name = img.split(os.sep)[-2]
                    label = self.name2label[name]
                    # 'pokemon\\bulbasaur\\00000000.png', 0
                    writer.writerow([img, label])
                print('writen into csv file:', filename)
        # read from csv file
        images, labels = [], []
        with open(os.path.join(self.root, filename)) as f:
            reader = csv.reader(f)
            for row in reader:
                # 'pokemon\\bulbasaur\\00000000.png', 0
                img, label = row
                label = int(label)
                images.append(img)
                labels.append(label)
        assert len(images) == len(labels)
        return images, labels

    def __len__(self):
        return len(self.images)

    def denormalize(self, x_hat):
        mean = [0.485, 0.456, 0.406]
        std = [0.229, 0.224, 0.225]
        # x_hat = (x-mean) / std
        # x = x_hat*std + mean
        # x: [c, h, w]
        # mean: [3] => [3, 1, 1]
        mean = torch.tensor(mean).unsqueeze(1).unsqueeze(1)
        # std: [3] => [3, 1, 1]
        std = torch.tensor(std).unsqueeze(1).unsqueeze(1)
        # print(mean.shape, std.shape)
        # 广播：[3, 1, 1] => [3, h, w]，对应元素相乘，对应元素相加
        x = x_hat * std + mean
        return x

    def __getitem__(self, idx):
        # idx~[0~len(images)]
        # self.images, self.labels
        # img: 'pokemon\\bulbasaur\\00000000.png'
        # label: 0
        img, label = self.images[idx], self.labels[idx]
        tf = transforms.Compose([
            lambda x: Image.open(x).convert('RGB'),  # string path= > image data
            transforms.Resize((int(self.resize * 1.25), int(self.resize * 1.25))),
            transforms.RandomRotation(15),
            transforms.CenterCrop(self.resize),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
        ])
        img = tf(img)
        label = torch.tensor(label)
        return img, label

# %%
batchsz = 32
lr = 1e-3
epochs = 10

# %%
device = torch.device('cuda')
torch.manual_seed(1234)

# %% [markdown]
# # 数据加载

# %%
train_db = Pokemon('./data/pokemon', 224, mode='train')
val_db = Pokemon('./data/pokemon', 224, mode='val')
test_db = Pokemon('./data/pokemon', 224, mode='test')
# train_loader = DataLoader(train_db, batch_size=batchsz, shuffle=True, num_workers=4)
train_loader = DataLoader(train_db, batch_size=batchsz, shuffle=True)
# val_loader = DataLoader(val_db, batch_size=batchsz, num_workers=2)
val_loader = DataLoader(val_db, batch_size=batchsz)
# test_loader = DataLoader(test_db, batch_size=batchsz, num_workers=2)
test_loader = DataLoader(test_db, batch_size=batchsz)
# Out:
# {'bulbasaur': 0, 'charmander': 1, 'mewtwo': 2, 'pikachu': 3, 'squirtle': 4}
# {'bulbasaur': 0, 'charmander': 1, 'mewtwo': 2, 'pikachu': 3, 'squirtle': 4}
# {'bulbasaur': 0, 'charmander': 1, 'mewtwo': 2, 'pikachu': 3, 'squirtle': 4}

# %% [markdown]
# # 模型加载

# %%
# Tensor二维化
class Flatten(nn.Module):
    def __init__(self):
        super(Flatten, self).__init__()

    def forward(self, x):
        shape = torch.prod(torch.tensor(x.shape[1:])).item()
        return x.view(-1, shape)

# %%
# 加载预训练模型
trained_model = resnet18(pretrained=True)
model = nn.Sequential(*list(trained_model.children())[: -1],  # [b, 512, 1, 1]
                      Flatten(),  # [b, 512, 1, 1] => [b, 512]
                      nn.Linear(512, 5)  # [b, 512] => [b, 5]
                      ).to(device)
# x = torch.randn(2, 3, 224, 224)
# print(model(x).shape)
optimizer = optim.Adam(model.parameters(), lr=lr)
criteon = nn.CrossEntropyLoss()
# Out:
# d:\ProgramData\Anaconda3\envs\DL_Basic\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# d:\ProgramData\Anaconda3\envs\DL_Basic\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# # 模型训练

# %%
def train(model, loader, epoch):
    for step, (x, y) in enumerate(train_loader):
        # x: [b, 3, 224, 224], y: [b]
        x, y = x.to(device), y.to(device)
        model.train()
        logits = model(x)
        loss = criteon(logits, y)
        print("epoch: {}, traing step: {}, training loss: {}".format(epoch, step, loss.item()))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %% [markdown]
# # 模型评估

# %%
# 模型评估
def evalute(model, loader):
    model.eval()
    correct = 0
    total = len(loader.dataset)
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        with torch.no_grad():
            logits = model(x)
            pred = logits.argmax(dim=1)
        correct += torch.eq(pred, y).sum().float().item()
    return correct / total

# %%
def main():
    best_acc, best_epoch = 0, 0
    global_step = 0
    for epoch in range(epochs):
        train(model, train_loader, epoch)
        global_step += 1
        if epoch % 1 == 0:
            val_acc = evalute(model, val_loader)
            if val_acc > best_acc:
                best_epoch = epoch
                best_acc = val_acc
                torch.save(model.state_dict(), './model/best.mdl')
    print('best acc:', best_acc, 'best epoch:', best_epoch)
    model.load_state_dict(torch.load('./model/best.mdl'))
    print('loaded from ckpt!')
    test_acc = evalute(model, test_loader)
    print('test acc:', test_acc)

# %%
if __name__ == '__main__':
    main()
# Out:
# epoch: 0, traing step: 0, training loss: 1.765452265739441
# d:\ProgramData\Anaconda3\envs\DL_Basic\lib\site-packages\PIL\Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# epoch: 0, traing step: 1, training loss: 0.9145488142967224
# epoch: 0, traing step: 2, training loss: 0.3724343180656433
# epoch: 0, traing step: 3, training loss: 0.553935706615448
# epoch: 0, traing step: 4, training loss: 0.1549140214920044
# epoch: 0, traing step: 5, training loss: 0.35490691661834717
# epoch: 0, traing step: 6, training loss: 0.4270232021808624
# epoch: 0, traing step: 7, training loss: 0.19795778393745422
# epoch: 0, traing step: 8, training loss: 0.11685838550329208
# epoch: 0, traing step: 9, training loss: 0.44310757517814636
# epoch: 0, traing step: 10, training loss: 0.1910984069108963
# epoch: 0, traing step: 11, training loss: 1.0186823606491089
# epoch: 0, traing step: 12, training loss: 0.1295214742422104
# epoch: 0, traing step: 13, training loss: 0.19655130803585052
# epoch: 0, traing step: 14, training loss: 0.11039809882640839
# epoch: 0, traing step: 15, training loss: 0.15897434949874878
# epoch: 0, traing step: 16, training loss: 0.3864029049873352
# epoch: 0, traing step: 17, training loss: 0.41495808959007263
# epoch: 0, traing step: 18, training loss: 0.6940008997917175
# epoch: 0, traing step: 19, training loss: 0.07171330600976944
# epoch: 0, traing step: 20, training loss: 0.13644897937774658
# epoch: 0, traing step: 21, training loss: 0.1715802252292633
# epoch: 1, traing step: 0, training loss: 0.4519255459308624
# epoch: 1, traing step: 1, training loss: 0.09193328768014908
# epoch: 1, traing step: 2, training loss: 0.10245814919471741
# epoch: 1, traing step: 3, training loss: 0.3150085508823395
# epoch: 1, traing step: 4, training loss: 0.12528589367866516
# epoch: 1, traing step: 5, training loss: 0.18154922127723694
# epoch: 1, traing step: 6, training loss: 0.5389752388000488
# epoch: 1, traing step: 7, training loss: 0.2712295651435852
# epoch: 1, traing step: 8, training loss: 0.2910713851451874
# epoch: 1, traing step: 9, training loss: 0.33034488558769226
# epoch: 1, traing step: 10, training loss: 0.4011290371417999
# epoch: 1, traing step: 11, training loss: 0.07153604179620743
# epoch: 1, traing step: 12, training loss: 0.6263843774795532
# epoch: 1, traing step: 13, training loss: 0.5301997065544128
# epoch: 1, traing step: 14, training loss: 0.2971644103527069
# epoch: 1, traing step: 15, training loss: 0.39028793573379517
# epoch: 1, traing step: 16, training loss: 0.06071333959698677
# epoch: 1, traing step: 17, training loss: 0.16529837250709534
# epoch: 1, traing step: 18, training loss: 0.10029004514217377
# epoch: 1, traing step: 19, training loss: 0.17873744666576385
# epoch: 1, traing step: 20, training loss: 0.13690252602100372
# epoch: 1, traing step: 21, training loss: 0.5724811553955078
# epoch: 2, traing step: 0, training loss: 0.15240752696990967
# epoch: 2, traing step: 1, training loss: 0.07213196903467178
# epoch: 2, traing step: 2, training loss: 0.025548841804265976
# epoch: 2, traing step: 3, training loss: 0.3659098148345947
# epoch: 2, traing step: 4, training loss: 0.13890047371387482
# epoch: 2, traing step: 5, training loss: 0.020186692476272583
# epoch: 2, traing step: 6, training loss: 0.1545419842004776
# epoch: 2, traing step: 7, training loss: 0.07567957043647766
# epoch: 2, traing step: 8, training loss: 0.14918400347232819
# epoch: 2, traing step: 9, training loss: 0.21097153425216675
# epoch: 2, traing step: 10, training loss: 0.14215248823165894
# epoch: 2, traing step: 11, training loss: 0.11742797493934631
# epoch: 2, traing step: 12, training loss: 0.04398833587765694
# epoch: 2, traing step: 13, training loss: 0.07780434191226959
# epoch: 2, traing step: 14, training loss: 0.15124176442623138
# epoch: 2, traing step: 15, training loss: 0.2251013070344925
# epoch: 2, traing step: 16, training loss: 0.08455171436071396
# epoch: 2, traing step: 17, training loss: 0.333244651556015
# epoch: 2, traing step: 18, training loss: 0.0944690853357315
# epoch: 2, traing step: 19, training loss: 0.1712694764137268
# epoch: 2, traing step: 20, training loss: 0.013454684056341648
# epoch: 2, traing step: 21, training loss: 0.22264574468135834
# epoch: 3, traing step: 0, training loss: 0.09998709708452225
# epoch: 3, traing step: 1, training loss: 0.1551184058189392
# epoch: 3, traing step: 2, training loss: 0.035924628376960754
# epoch: 3, traing step: 3, training loss: 0.18303875625133514
# epoch: 3, traing step: 4, training loss: 0.08295072615146637
# epoch: 3, traing step: 5, training loss: 0.23630820214748383
# epoch: 3, traing step: 6, training loss: 0.0495867058634758
# epoch: 3, traing step: 7, training loss: 0.15561853349208832
# epoch: 3, traing step: 8, training loss: 0.09001151472330093
# epoch: 3, traing step: 9, training loss: 0.10194055736064911
# epoch: 3, traing step: 10, training loss: 0.08685407042503357
# epoch: 3, traing step: 11, training loss: 0.0181985255330801
# epoch: 3, traing step: 12, training loss: 0.23643949627876282
# epoch: 3, traing step: 13, training loss: 0.08264272660017014
# epoch: 3, traing step: 14, training loss: 0.30055221915245056
# epoch: 3, traing step: 15, training loss: 0.2941998243331909
# epoch: 3, traing step: 16, training loss: 0.47341927886009216
# epoch: 3, traing step: 17, training loss: 0.11024770885705948
# epoch: 3, traing step: 18, training loss: 0.06703120470046997
# epoch: 3, traing step: 19, training loss: 0.051979079842567444
# epoch: 3, traing step: 20, training loss: 0.06953304260969162
# epoch: 3, traing step: 21, training loss: 0.38395991921424866
# epoch: 4, traing step: 0, training loss: 0.035678524523973465
# epoch: 4, traing step: 1, training loss: 0.07366359233856201
# epoch: 4, traing step: 2, training loss: 0.09982403367757797
# epoch: 4, traing step: 3, training loss: 0.03541174158453941
# epoch: 4, traing step: 4, training loss: 0.029698068276047707
# epoch: 4, traing step: 5, training loss: 0.03781796991825104
# epoch: 4, traing step: 6, training loss: 0.10441107302904129
# epoch: 4, traing step: 7, training loss: 0.426222026348114
# epoch: 4, traing step: 8, training loss: 0.02694844640791416
# epoch: 4, traing step: 9, training loss: 0.026076050475239754
# epoch: 4, traing step: 10, training loss: 0.09808921813964844
# epoch: 4, traing step: 11, training loss: 0.021978002041578293
# epoch: 4, traing step: 12, training loss: 0.11530055850744247
# epoch: 4, traing step: 13, training loss: 0.049245040863752365
# epoch: 4, traing step: 14, training loss: 0.02151639200747013
# epoch: 4, traing step: 15, training loss: 0.10202547907829285
# epoch: 4, traing step: 16, training loss: 0.010334733873605728
# epoch: 4, traing step: 17, training loss: 0.2154746651649475
# epoch: 4, traing step: 18, training loss: 0.024958547204732895
# epoch: 4, traing step: 19, training loss: 0.008227542974054813
# epoch: 4, traing step: 20, training loss: 0.006283998489379883
# epoch: 4, traing step: 21, training loss: 0.003754958976060152
# epoch: 5, traing step: 0, training loss: 0.02112620510160923
# epoch: 5, traing step: 1, training loss: 0.16038669645786285
# epoch: 5, traing step: 2, training loss: 0.016413630917668343
# epoch: 5, traing step: 3, training loss: 0.017414776608347893
# epoch: 5, traing step: 4, training loss: 0.18682748079299927
# epoch: 5, traing step: 5, training loss: 0.06921285390853882
# epoch: 5, traing step: 6, training loss: 0.03479520604014397
# epoch: 5, traing step: 7, training loss: 0.014767476357519627
# epoch: 5, traing step: 8, training loss: 0.2945520579814911
# epoch: 5, traing step: 9, training loss: 0.05886322632431984
# epoch: 5, traing step: 10, training loss: 0.024852653965353966
# epoch: 5, traing step: 11, training loss: 0.009244781918823719
# epoch: 5, traing step: 12, training loss: 0.05943549424409866
# epoch: 5, traing step: 13, training loss: 0.0442420095205307
# epoch: 5, traing step: 14, training loss: 0.07266917824745178
# epoch: 5, traing step: 15, training loss: 0.20706333220005035
# epoch: 5, traing step: 16, training loss: 0.06212473288178444
# epoch: 5, traing step: 17, training loss: 0.007196588907390833
# epoch: 5, traing step: 18, training loss: 0.05138491466641426
# epoch: 5, traing step: 19, training loss: 0.04764401912689209
# epoch: 5, traing step: 20, training loss: 0.020357338711619377
# epoch: 5, traing step: 21, training loss: 0.02690616436302662
# epoch: 6, traing step: 0, training loss: 0.022608822211623192
# epoch: 6, traing step: 1, training loss: 0.013886513188481331
# epoch: 6, traing step: 2, training loss: 0.08837594836950302
# epoch: 6, traing step: 3, training loss: 0.03850764036178589
# epoch: 6, traing step: 4, training loss: 0.010328453034162521
# epoch: 6, traing step: 5, training loss: 0.010237317532300949
# epoch: 6, traing step: 6, training loss: 0.19817452132701874
# epoch: 6, traing step: 7, training loss: 0.013277019374072552
# epoch: 6, traing step: 8, training loss: 0.0032549200113862753
# epoch: 6, traing step: 9, training loss: 0.008455410599708557
# epoch: 6, traing step: 10, training loss: 0.008745789527893066
# epoch: 6, traing step: 11, training loss: 0.05869127810001373
# epoch: 6, traing step: 12, training loss: 0.001804365194402635
# epoch: 6, traing step: 13, training loss: 0.10088039934635162
# epoch: 6, traing step: 14, training loss: 0.046482305973768234
# epoch: 6, traing step: 15, training loss: 0.10268731415271759
# epoch: 6, traing step: 16, training loss: 0.07929879426956177
# epoch: 6, traing step: 17, training loss: 0.01600717566907406
# epoch: 6, traing step: 18, training loss: 0.0642702504992485
# epoch: 6, traing step: 19, training loss: 0.2479233741760254
# epoch: 6, traing step: 20, training loss: 0.0984782874584198
# epoch: 6, traing step: 21, training loss: 0.0032336353324353695
# epoch: 7, traing step: 0, training loss: 0.019060499966144562
# epoch: 7, traing step: 1, training loss: 0.09605152159929276
# epoch: 7, traing step: 2, training loss: 0.19754084944725037
# epoch: 7, traing step: 3, training loss: 0.016063924878835678
# epoch: 7, traing step: 4, training loss: 0.006650799419730902
# epoch: 7, traing step: 5, training loss: 0.04479700326919556
# epoch: 7, traing step: 6, training loss: 0.006159959826618433
# epoch: 7, traing step: 7, training loss: 0.0950072705745697
# epoch: 7, traing step: 8, training loss: 0.10793476551771164
# epoch: 7, traing step: 9, training loss: 0.054972436279058456
# epoch: 7, traing step: 10, training loss: 0.3396475315093994
# epoch: 7, traing step: 11, training loss: 0.006284868810325861
# epoch: 7, traing step: 12, training loss: 0.18975017964839935
# epoch: 7, traing step: 13, training loss: 0.09036852419376373
# epoch: 7, traing step: 14, training loss: 0.09380881488323212
# epoch: 7, traing step: 15, training loss: 0.03701386600732803
# epoch: 7, traing step: 16, training loss: 0.4225381910800934
# epoch: 7, traing step: 17, training loss: 0.04465913027524948
# epoch: 7, traing step: 18, training loss: 0.039848968386650085
# epoch: 7, traing step: 19, training loss: 0.04767797514796257
# epoch: 7, traing step: 20, training loss: 0.14368422329425812
# epoch: 7, traing step: 21, training loss: 0.20395109057426453
# epoch: 8, traing step: 0, training loss: 0.11468421667814255
# epoch: 8, traing step: 1, training loss: 0.10512962192296982
# epoch: 8, traing step: 2, training loss: 0.02279360219836235
# epoch: 8, traing step: 3, training loss: 0.15841911733150482
# epoch: 8, traing step: 4, training loss: 0.04404177516698837
# epoch: 8, traing step: 5, training loss: 0.011683388613164425
# epoch: 8, traing step: 6, training loss: 0.05078544467687607
# epoch: 8, traing step: 7, training loss: 0.10625836998224258
# epoch: 8, traing step: 8, training loss: 0.19451312720775604
# epoch: 8, traing step: 9, training loss: 0.1272527426481247
# epoch: 8, traing step: 10, training loss: 0.106266550719738
# epoch: 8, traing step: 11, training loss: 0.05638487637042999
# epoch: 8, traing step: 12, training loss: 0.010325913317501545
# epoch: 8, traing step: 13, training loss: 0.08335261046886444
# epoch: 8, traing step: 14, training loss: 0.021882647648453712
# epoch: 8, traing step: 15, training loss: 0.3290131688117981
# epoch: 8, traing step: 16, training loss: 0.025324322283267975
# epoch: 8, traing step: 17, training loss: 0.04364030808210373
# epoch: 8, traing step: 18, training loss: 0.4385744333267212
# epoch: 8, traing step: 19, training loss: 0.2647702991962433
# epoch: 8, traing step: 20, training loss: 0.011760465800762177
# epoch: 8, traing step: 21, training loss: 0.02033059112727642
# epoch: 9, traing step: 0, training loss: 0.045898646116256714
# epoch: 9, traing step: 1, training loss: 0.09873736649751663
# epoch: 9, traing step: 2, training loss: 0.07873857766389847
# epoch: 9, traing step: 3, training loss: 0.17404277622699738
# epoch: 9, traing step: 4, training loss: 0.05131786689162254
# epoch: 9, traing step: 5, training loss: 0.45283371210098267
# epoch: 9, traing step: 6, training loss: 0.07851144671440125
# epoch: 9, traing step: 7, training loss: 0.034444499760866165
# epoch: 9, traing step: 8, training loss: 0.2137884497642517
# epoch: 9, traing step: 9, training loss: 0.12331646680831909
# epoch: 9, traing step: 10, training loss: 0.04974592849612236
# epoch: 9, traing step: 11, training loss: 0.24568670988082886
# epoch: 9, traing step: 12, training loss: 0.01784106157720089
# epoch: 9, traing step: 13, training loss: 0.14290621876716614
# epoch: 9, traing step: 14, training loss: 0.054034531116485596
# epoch: 9, traing step: 15, training loss: 0.07798271626234055
# epoch: 9, traing step: 16, training loss: 0.11502004414796829
# epoch: 9, traing step: 17, training loss: 0.07472889870405197
# epoch: 9, traing step: 18, training loss: 0.11654341965913773
# epoch: 9, traing step: 19, training loss: 0.08559402078390121
# epoch: 9, traing step: 20, training loss: 0.09534644335508347
# epoch: 9, traing step: 21, training loss: 0.17060412466526031
# best acc: 0.9613733905579399 best epoch: 4
# loaded from ckpt!
# test acc: 0.9358974358974359
# epoch: 6, traing step: 7, training loss: 0.12729626893997192
# epoch: 6, traing step: 8, training loss: 0.07294700294733047
# epoch: 6, traing step: 9, training loss: 0.05210501700639725
# epoch: 6, traing step: 10, training loss: 0.039170973002910614
# epoch: 6, traing step: 11, training loss: 0.03699680045247078
# epoch: 6, traing step: 12, training loss: 0.012232406064867973
# epoch: 6, traing step: 13, training loss: 0.004225059412419796
# epoch: 6, traing step: 14, training loss: 0.23048371076583862
# epoch: 6, traing step: 15, training loss: 0.08058521151542664
# epoch: 6, traing step: 16, training loss: 0.022507579997181892
# epoch: 6, traing step: 17, training loss: 0.002821570262312889
# epoch: 6, traing step: 18, training loss: 0.4455980658531189
# epoch: 6, traing step: 19, training loss: 0.07919394224882126
# epoch: 6, traing step: 20, training loss: 0.003211475443094969
# epoch: 6, traing step: 21, training loss: 0.008389432914555073
# epoch: 7, traing step: 0, training loss: 0.146104633808136
# epoch: 7, traing step: 1, training loss: 0.03505093604326248
# epoch: 7, traing step: 2, training loss: 0.0672072023153305
# epoch: 7, traing step: 3, training loss: 0.08065833896398544
# epoch: 7, traing step: 4, training loss: 0.03238178417086601
# epoch: 7, traing step: 5, training loss: 0.38645437359809875
# epoch: 7, traing step: 6, training loss: 0.04059590399265289
# epoch: 7, traing step: 7, training loss: 0.003266706829890609
# epoch: 7, traing step: 8, training loss: 0.023912934586405754
# epoch: 7, traing step: 9, training loss: 0.205672487616539
# epoch: 7, traing step: 10, training loss: 0.23392508924007416
# epoch: 7, traing step: 11, training loss: 0.017250722274184227
# epoch: 7, traing step: 12, training loss: 0.19197139143943787
# epoch: 7, traing step: 13, training loss: 0.08306536823511124
# epoch: 7, traing step: 14, training loss: 0.07823140919208527
# epoch: 7, traing step: 15, training loss: 0.06226406991481781
# epoch: 7, traing step: 16, training loss: 0.5949620008468628
# epoch: 7, traing step: 17, training loss: 0.011478308588266373
# epoch: 7, traing step: 18, training loss: 0.24821770191192627
# epoch: 7, traing step: 19, training loss: 0.02527514100074768
# epoch: 7, traing step: 20, training loss: 0.08094102889299393
# epoch: 7, traing step: 21, training loss: 0.1367630809545517
# epoch: 8, traing step: 0, training loss: 0.022848227992653847
# epoch: 8, traing step: 1, training loss: 0.014972180128097534
# epoch: 8, traing step: 2, training loss: 0.19781601428985596
# epoch: 8, traing step: 3, training loss: 0.030511070042848587
# epoch: 8, traing step: 4, training loss: 0.075749970972538
# epoch: 8, traing step: 5, training loss: 0.11165593564510345
# epoch: 8, traing step: 6, training loss: 0.08311356604099274
# epoch: 8, traing step: 7, training loss: 0.027060464024543762
# epoch: 8, traing step: 8, training loss: 0.046703968197107315
# epoch: 8, traing step: 9, training loss: 0.023044081404805183
# epoch: 8, traing step: 10, training loss: 0.04292780160903931
# epoch: 8, traing step: 11, training loss: 0.00979086197912693
# epoch: 8, traing step: 12, training loss: 0.017800960689783096
# epoch: 8, traing step: 13, training loss: 0.022895794361829758
# epoch: 8, traing step: 14, training loss: 0.04809652268886566
# epoch: 8, traing step: 15, training loss: 0.011012724600732327
# epoch: 8, traing step: 16, training loss: 0.006570088677108288
# epoch: 8, traing step: 17, training loss: 0.11281359195709229
# epoch: 8, traing step: 18, training loss: 0.027477484196424484
# epoch: 8, traing step: 19, training loss: 0.2021254450082779
# epoch: 8, traing step: 20, training loss: 0.18567714095115662
# epoch: 8, traing step: 21, training loss: 0.10193649679422379
# epoch: 9, traing step: 0, training loss: 0.1977437138557434
# epoch: 9, traing step: 1, training loss: 0.02200753428041935
# epoch: 9, traing step: 2, training loss: 0.0038316184654831886
# epoch: 9, traing step: 3, training loss: 0.022634856402873993
# epoch: 9, traing step: 4, training loss: 0.15106038749217987
# epoch: 9, traing step: 5, training loss: 0.004586056340485811
# epoch: 9, traing step: 6, training loss: 0.025583913549780846
# epoch: 9, traing step: 7, training loss: 0.3499479591846466
# epoch: 9, traing step: 8, training loss: 0.08632206916809082
# epoch: 9, traing step: 9, training loss: 0.003845514729619026
# epoch: 9, traing step: 10, training loss: 0.010240335017442703
# epoch: 9, traing step: 11, training loss: 0.0404849536716938
# epoch: 9, traing step: 12, training loss: 0.03420436382293701
# epoch: 9, traing step: 13, training loss: 0.03625822439789772
# epoch: 9, traing step: 14, training loss: 0.16860418021678925
# epoch: 9, traing step: 15, training loss: 0.05446682125329971
# epoch: 9, traing step: 16, training loss: 0.01657269522547722
# epoch: 9, traing step: 17, training loss: 0.10316377878189087
# epoch: 9, traing step: 18, training loss: 0.08697546273469925
# epoch: 9, traing step: 19, training loss: 0.00993320532143116
# epoch: 9, traing step: 20, training loss: 0.06469977647066116
# epoch: 9, traing step: 21, training loss: 0.2487119436264038
# best acc: 0.9570815450643777 best epoch: 7
# loaded from ckpt!
# test acc: 0.9316239316239316
